# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import scipy.stats


def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m-h, m+h

# %%
aging_data = pd.read_csv('4.xlsx_scaled.csv', header=None)

# %%
aging_value = aging_data.iloc[:, 82];

# %%
aging_value_rows = aging_value[aging_value > 0]

# %%
non_aging_value_rows = aging_value[aging_value == 0]
p = []

# %%
from pylab import plot, show, savefig, xlim, figure, hold, ylim, legend, boxplot, setp, axes
from scipy.stats import ranksums
for i in range(0,82):
    feature_column = aging_data.iloc[:, i]
    feature_column_aging_value = feature_column.iloc[aging_value_rows.index]
    feature_column_non_aging_value = feature_column.iloc[non_aging_value_rows.index]
    confidance_interval_aging = mean_confidence_interval(feature_column_aging_value)
    confidance_interval_non_aging = mean_confidence_interval(feature_column_non_aging_value)
    pair = [confidance_interval_aging, confidance_interval_non_aging]
    fig = plt.figure()
    plt.boxplot(pair)
    index = str(i+1)
    fig.savefig("box_plots4/box"+index)
    p.append(ranksums(feature_column_aging_value, feature_column_non_aging_value) )
    print(p[i])
# Out:
# RanksumsResult(statistic=2.5497440280925954, pvalue=0.01078020368759581)
# RanksumsResult(statistic=2.3535336442751316, pvalue=0.01859592495091004)
# RanksumsResult(statistic=5.533529208266247, pvalue=3.1385069012471036e-08)
# RanksumsResult(statistic=8.691723618499864, pvalue=3.569816614346118e-18)
# RanksumsResult(statistic=7.702744007137094, pvalue=1.3317498614146612e-14)
# RanksumsResult(statistic=9.004867463380261, pvalue=2.159264645236459e-19)
# RanksumsResult(statistic=0.8363715350602994, pvalue=0.40294592096475923)
# RanksumsResult(statistic=1.4804965324408617, pvalue=0.13874078543449378)
# RanksumsResult(statistic=0.8829467271785862, pvalue=0.3772650553468465)
# RanksumsResult(statistic=0.28638788345074234, pvalue=0.7745810538523666)
# RanksumsResult(statistic=2.740008642703469, pvalue=0.0061437568787662345)
# RanksumsResult(statistic=2.6468582584668954, pvalue=0.00812433979685105)
# RanksumsResult(statistic=2.216780952523566, pvalue=0.02663806373565527)
# RanksumsResult(statistic=6.138015744269543, pvalue=8.355858304996471e-10)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=9.623227460865602, pvalue=6.379733380819224e-22)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=8.249754774143357, pvalue=1.5871988438871138e-16)
# RanksumsResult(statistic=9.15549361661387, pvalue=5.410985930178681e-20)
# RanksumsResult(statistic=8.101110543978612, pvalue=5.445973626733896e-16)
# RanksumsResult(statistic=8.580735926643522, pvalue=9.426807046803756e-18)
# RanksumsResult(statistic=7.966339775295909, pvalue=1.634431637943158e-15)
# RanksumsResult(statistic=9.827365536958519, pvalue=8.583476709774239e-23)
# RanksumsResult(statistic=5.5583032466270375, pvalue=2.7240980304127993e-08)
# RanksumsResult(statistic=5.385875939635933, pvalue=7.209267829896909e-08)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=8.231917466523587, pvalue=1.8424018239310432e-16)
# RanksumsResult(statistic=8.854241310146653, pvalue=8.425493057251387e-19)
# RanksumsResult(statistic=9.353685923500198, pvalue=8.464532567773376e-21)
# RanksumsResult(statistic=10.778688610012887, pvalue=4.3402921005633274e-27)
# RanksumsResult(statistic=8.410290542721281, pvalue=4.0899632561892604e-17)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=4.418697482030658, pvalue=9.9297522955005e-06)
# RanksumsResult(statistic=5.77829670727086, pvalue=7.546064857849797e-09)
# RanksumsResult(statistic=5.593977861866576, pvalue=2.2192526451925545e-08)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=2.6359576815881476, pvalue=0.008390019430553557)
# RanksumsResult(statistic=7.873189391059335, pvalue=3.4571269941143742e-15)
# RanksumsResult(statistic=8.26957400483199, pvalue=1.3443850479858556e-16)
# RanksumsResult(statistic=7.736436699307769, pvalue=1.022418518681936e-14)
# RanksumsResult(statistic=7.891026698679105, pvalue=2.9971052064030857e-15)
# RanksumsResult(statistic=9.462691692287677, pvalue=3.001162418546575e-21)
# RanksumsResult(statistic=8.729380156808267, pvalue=2.5607213409089765e-18)
# RanksumsResult(statistic=8.61046477267647, pvalue=7.276495797869038e-18)
# RanksumsResult(statistic=8.951355540520954, pvalue=3.5114341548621955e-19)
# RanksumsResult(statistic=8.759109002841216, pvalue=1.967997415242606e-18)
# RanksumsResult(statistic=8.725416310670541, pvalue=2.6520317112312584e-18)
# RanksumsResult(statistic=8.53713361912853, pvalue=1.375924109983406e-17)
# RanksumsResult(statistic=9.99781092088076, pvalue=1.5580301835906603e-23)
# RanksumsResult(statistic=8.761090925910079, pvalue=1.9336974395806757e-18)
# RanksumsResult(statistic=6.168735551836924, pvalue=6.883824397896866e-10)
# RanksumsResult(statistic=2.1622780681298264, pvalue=0.030596749183673777)
# RanksumsResult(statistic=7.946520544607276, pvalue=1.9182307990755034e-15)
# RanksumsResult(statistic=8.564880542092617, pvalue=1.0818795005903463e-17)
# RanksumsResult(statistic=8.860187079353244, pvalue=7.98802759499034e-19)
# RanksumsResult(statistic=9.801600537063296, pvalue=1.10815606427994e-22)

# %%
# %store -r result_array

# %%
len(result_array[1])
# Out:
# 82

# %%
for i in range(0, 82):
    if (p[i][1] <= 0.05):
        result_array[3].append(1)
           
    else:
        result_array[3].append(0)

# %%
len(result_array[3])
# Out:
# 82

# %%
# %store result_array
# Out:
# Stored 'result_array' (list)
