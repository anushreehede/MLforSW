# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import scipy.stats


def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m-h, m+h

# %%
aging_data = pd.read_csv('5.xlsx_scaled.csv', header=None)

# %%
aging_value = aging_data.iloc[:, 82];

# %%
aging_value_rows = aging_value[aging_value > 0]

# %%
non_aging_value_rows = aging_value[aging_value == 0]
p = []

# %%
from pylab import plot, show, savefig, xlim, figure, hold, ylim, legend, boxplot, setp, axes
from scipy.stats import ranksums
for i in range(0,82):
    feature_column = aging_data.iloc[:, i]
    feature_column_aging_value = feature_column.iloc[aging_value_rows.index]
    feature_column_non_aging_value = feature_column.iloc[non_aging_value_rows.index]
    confidance_interval_aging = mean_confidence_interval(feature_column_aging_value)
    confidance_interval_non_aging = mean_confidence_interval(feature_column_non_aging_value)
    pair = [confidance_interval_aging, confidance_interval_non_aging]
    fig = plt.figure()
    plt.boxplot(pair)
    index = str(i+1)
    fig.savefig("box_plots5/box"+index)
    p.append(ranksums(feature_column_aging_value, feature_column_non_aging_value) )
    print(p[i])
# Out:
# RanksumsResult(statistic=13.617869678520512, pvalue=3.135820376349378e-42)
# RanksumsResult(statistic=14.65810928155848, pvalue=1.1955595271260914e-48)
# RanksumsResult(statistic=14.602907279148958, pvalue=2.6911975330246287e-48)
# RanksumsResult(statistic=20.35285791019169, pvalue=4.3798025308347306e-92)
# RanksumsResult(statistic=20.324655017994925, pvalue=7.783416871064587e-92)
# RanksumsResult(statistic=19.939100845402574, pvalue=1.8638481122503002e-88)
# RanksumsResult(statistic=13.80617557459037, pvalue=2.339250178212644e-43)
# RanksumsResult(statistic=13.417697931465428, pvalue=4.76279463086208e-41)
# RanksumsResult(statistic=14.467223852665745, pvalue=1.9519274093685639e-47)
# RanksumsResult(statistic=15.62629393441081, pvalue=4.820359353707402e-55)
# RanksumsResult(statistic=14.60978603334329, pvalue=2.4328080778364465e-48)
# RanksumsResult(statistic=13.343063448456919, pvalue=1.3000524169136944e-40)
# RanksumsResult(statistic=13.778488588958181, pvalue=3.433861362770633e-43)
# RanksumsResult(statistic=14.001876131419136, pvalue=1.5180955143735025e-44)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=10.914519280147747, pvalue=9.824768565224504e-28)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# RanksumsResult(statistic=20.172634550300174, pvalue=1.7031938596689684e-90)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=20.426288611216194, pvalue=9.764797296446471e-93)
# RanksumsResult(statistic=19.87306480513698, pvalue=6.961973351211433e-88)
# RanksumsResult(statistic=20.122075706971827, pvalue=4.728601252313191e-90)
# RanksumsResult(statistic=19.046926426397622, pvalue=6.967486750199112e-81)
# RanksumsResult(statistic=19.97125902126108, pvalue=9.7952993163871e-89)
# RanksumsResult(statistic=19.79344322533758, pvalue=3.390669123981844e-87)
# RanksumsResult(statistic=20.0594790438034, pvalue=1.6682253810007122e-89)
# RanksumsResult(statistic=18.761286158477954, pvalue=1.565648506091775e-78)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=19.951482602952375, pvalue=1.4550900055196455e-88)
# RanksumsResult(statistic=20.009952013604202, pvalue=4.51082593678881e-89)
# RanksumsResult(statistic=19.825945338905804, pvalue=1.7780866843606923e-87)
# RanksumsResult(statistic=18.372292608788438, pvalue=2.1896420955513567e-75)
# RanksumsResult(statistic=19.848645227747102, pvalue=1.1321233399472301e-87)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=18.725344667812564, pvalue=3.076736983032564e-78)
# RanksumsResult(statistic=18.133427869390232, pvalue=1.7359274535877585e-73)
# RanksumsResult(statistic=19.032137104879805, pvalue=9.24061902189707e-81)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=-4.9086789930758385, pvalue=9.169191958689234e-07)
# RanksumsResult(statistic=19.91726080083557, pvalue=2.883388232262388e-88)
# RanksumsResult(statistic=19.820786273260055, pvalue=1.9700656735441433e-87)
# RanksumsResult(statistic=19.831104404551553, pvalue=1.604773060484486e-87)
# RanksumsResult(statistic=20.037638999236393, pvalue=2.5875354036163035e-89)
# RanksumsResult(statistic=20.073924427611498, pvalue=1.2475390745459773e-89)
# RanksumsResult(statistic=19.82491352577665, pvalue=1.8149280254895063e-87)
# RanksumsResult(statistic=19.674268808920765, pvalue=3.583075258729981e-86)
# RanksumsResult(statistic=19.53497403648553, pvalue=5.537407094024474e-85)
# RanksumsResult(statistic=19.715197396377047, pvalue=1.596919189431459e-86)
# RanksumsResult(statistic=20.027492836799752, pvalue=3.172321007511281e-89)
# RanksumsResult(statistic=19.548387607164475, pvalue=4.257660287917765e-85)
# RanksumsResult(statistic=19.781577374352356, pvalue=4.290569914096908e-87)
# RanksumsResult(statistic=19.61132820804262, pvalue=1.2375749180583864e-85)
# RanksumsResult(statistic=20.784843673595784, pvalue=5.935722389165628e-96)
# RanksumsResult(statistic=19.22818159941829, pvalue=2.150367569039704e-82)
# RanksumsResult(statistic=19.71055423729587, pvalue=1.75039351311886e-86)
# RanksumsResult(statistic=19.59911841934768, pvalue=1.5732585384635092e-85)
# RanksumsResult(statistic=19.32018493676749, pvalue=3.6334646804569466e-83)
# RanksumsResult(statistic=19.32517203355838, pvalue=3.29882337376363e-83)

# %%
# %store -r result_array

# %%
for i in range(0, 82):
    if (p[i][1] <= 0.05):
        result_array[4].append(1)
           
    else:
        result_array[4].append(0)

# %%
len(result_array[4])
# Out:
# 82

# %%
# %store result_array
# Out:
# Stored 'result_array' (list)
