# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import scipy.stats


def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m-h, m+h

# %%
aging_data = pd.read_csv('6.xlsx_scaled.csv', header=None)

# %%
aging_value = aging_data.iloc[:, 82];

# %%
aging_value_rows = aging_value[aging_value > 0]

# %%
non_aging_value_rows = aging_value[aging_value == 0]
p = []

# %%
from pylab import plot, show, savefig, xlim, figure, hold, ylim, legend, boxplot, setp, axes
from scipy.stats import ranksums
for i in range(0,82):
    feature_column = aging_data.iloc[:, i]
    feature_column_aging_value = feature_column.iloc[aging_value_rows.index]
    feature_column_non_aging_value = feature_column.iloc[non_aging_value_rows.index]
    confidance_interval_aging = mean_confidence_interval(feature_column_aging_value)
    confidance_interval_non_aging = mean_confidence_interval(feature_column_non_aging_value)
    pair = [confidance_interval_aging, confidance_interval_non_aging]
    fig = plt.figure()
    plt.boxplot(pair)
    index = str(i+1)
    fig.savefig("box_plots6/box"+index)
    p.append(ranksums(feature_column_aging_value, feature_column_non_aging_value) )
    print(p[i])
# Out:
# RanksumsResult(statistic=6.354522775598826, pvalue=2.090746696877424e-10)
# RanksumsResult(statistic=6.149331323712689, pvalue=7.781028591300466e-10)
# RanksumsResult(statistic=6.360935008470268, pvalue=2.0052928582073773e-10)
# RanksumsResult(statistic=5.315741050425254, pvalue=1.0622412383098639e-07)
# RanksumsResult(statistic=5.8287196801405985, pvalue=5.585423485900765e-09)
# RanksumsResult(statistic=5.649177159740228, pvalue=1.6121764544691873e-08)
# RanksumsResult(statistic=6.348110542727384, pvalue=2.1797543958911802e-10)
# RanksumsResult(statistic=6.162155789455572, pvalue=7.176119763360904e-10)
# RanksumsResult(statistic=6.380171707084593, pvalue=1.76889537809929e-10)
# RanksumsResult(statistic=6.258339282527199, pvalue=3.890985978647318e-10)
# RanksumsResult(statistic=6.290400446884409, pvalue=3.16648065942899e-10)
# RanksumsResult(statistic=6.392996172827477, pvalue=1.626663347311038e-10)
# RanksumsResult(statistic=6.290400446884409, pvalue=3.16648065942899e-10)
# RanksumsResult(statistic=6.168568022327014, pvalue=6.891120435603051e-10)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=-2.4558851897622103, pvalue=0.014053804888386284)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# RanksumsResult(statistic=0.42961960238660074, pvalue=0.6674723753875516)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=6.0467355977696196, pvalue=1.4781002863526372e-09)
# RanksumsResult(statistic=5.174671927253534, pvalue=2.2831179238803058e-07)
# RanksumsResult(statistic=6.098033460741154, pvalue=1.0738127274348583e-09)
# RanksumsResult(statistic=4.289783790994566, pvalue=1.788471448934686e-05)
# RanksumsResult(statistic=6.2134536524271065, pvalue=5.183252558775963e-10)
# RanksumsResult(statistic=5.597879296768694, pvalue=2.169897368017728e-08)
# RanksumsResult(statistic=2.4430607240193267, pvalue=0.014563286641456065)
# RanksumsResult(statistic=4.110241270594195, pvalue=3.9524592124713705e-05)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=6.277575981141524, pvalue=3.4389222134861113e-10)
# RanksumsResult(statistic=6.277575981141524, pvalue=3.4389222134861113e-10)
# RanksumsResult(statistic=4.328257188223216, pvalue=1.5029390472628843e-05)
# RanksumsResult(statistic=4.98230494111028, pvalue=6.283131495617477e-07)
# RanksumsResult(statistic=6.4314695700561275, pvalue=1.263760850357558e-10)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=6.803379076599752, pvalue=1.021932734171723e-11)
# RanksumsResult(statistic=6.7456689807567765, pvalue=1.5232353896248126e-11)
# RanksumsResult(statistic=6.918799268285705, pvalue=4.554877203629835e-12)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=0.0, pvalue=1.0)
# RanksumsResult(statistic=1.3145077386455695, pvalue=0.18867539558740598)
# RanksumsResult(statistic=5.9056664745979, pvalue=3.51223908140341e-09)
# RanksumsResult(statistic=5.867193077369249, pvalue=4.4323443683619945e-09)
# RanksumsResult(statistic=5.931315406083667, pvalue=3.005172941538361e-09)
# RanksumsResult(statistic=5.803070748654831, pvalue=6.511130138335075e-09)
# RanksumsResult(statistic=3.340773326021179, pvalue=0.0008354540158072668)
# RanksumsResult(statistic=5.713299488454646, pvalue=1.1080641758467056e-08)
# RanksumsResult(statistic=6.098033460741154, pvalue=1.0738127274348583e-09)
# RanksumsResult(statistic=6.316049378370176, pvalue=2.6833434301215643e-10)
# RanksumsResult(statistic=5.918490940340783, pvalue=3.249088991593584e-09)
# RanksumsResult(statistic=5.302916584682371, pvalue=1.1396700609142126e-07)
# RanksumsResult(statistic=6.521240830256313, pvalue=6.972812196869972e-11)
# RanksumsResult(statistic=5.367038913396788, pvalue=8.003979302372113e-08)
# RanksumsResult(statistic=6.713607816399567, pvalue=1.8987020510361626e-11)
# RanksumsResult(statistic=2.5520686828338373, pvalue=0.0107085406515169)
# RanksumsResult(statistic=4.244898160894473, pvalue=2.1869272117732675e-05)
# RanksumsResult(statistic=6.6238365561993815, pvalue=3.499937461359318e-11)
# RanksumsResult(statistic=6.50841636451343, pvalue=7.594717327443072e-11)
# RanksumsResult(statistic=6.726432282142451, pvalue=1.738735096318084e-11)
# RanksumsResult(statistic=6.418645104313244, pvalue=1.3749251672502982e-10)

# %%
# %store -r result_array

# %%
for i in range(0, 82):
    if (p[i][1] <= 0.05):
        result_array[5].append(1)
           
    else:
        result_array[5].append(0)

# %%
len(result_array[5])
# Out:
# 82

# %%
# %store result_array
# Out:
# Stored 'result_array' (list)
